# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\Apoorva\Documents\Apoorva\Cityu\Real Estate Project\Facilities.csv")

# %%
list(set(list(df['Dataset'])))
# Out:
# ['Public Market Information',
#  'Residential Special Child Care Centre',
#  nan,
#  'Hard-surface Pitches',
#  'Water Sports Centres',
#  'List of community halls / community centres',
#  'Supported Hostel for Mentally / Physically Handicapped',
#  'Subvented and Contract Homes providing Subsidised Residential Care Services for the Elderly',
#  'English Schools Foundation (Secondary)',
#  'Water Dispensers in FEHD Public Markets',
#  'Barbecue Areas (LCSD)',
#  'Aided Standalone Child Care Centre',
#  'Badminton Courts',
#  'FEHD facility and service locations',
#  'Table Tennis Tables',
#  'Neighbourhood Elderly Centres',
#  'Police Stations (Districts / Divisons)',
#  'Mutual Help Child Care Centre',
#  'Government Primary Schools',
#  'List of licensed club-houses',
#  'Kindergarten-cum-child Care Centres',
#  'International Schools (Primary)',
#  'District Support Centre for Persons with Disabilities',
#  'Hotels (Licensed)',
#  'Caput Secondary Schools',
# ...

# %%
l = ['Waste Management Facilities', 'Recycling Organisations and Collection Points']

# %%
df1 = df[df['Dataset'].isin(l)]

# %%
df1.to_csv('WasteManagement.csv', index = False)

# %%
df1.head(2)
# Out:
#                                          Dataset Facility Name  \
# 0  Recycling Organisations and Collection Points      7-ELEVEN
# 1  Recycling Organisations and Collection Points      7-ELEVEN
#
#                                              Address  \
# 0  Shop 3, G/F, Kai Tin Shopping Centre, 50 Kai T...
# 1  Shop 8-9, Shan King Commercial Centre, Shan Ki...
#
#   Name of Recycling Organisations Types of Material Collection   District  \
# 0                        7-ELEVEN       RECHARGEABLE BATTERIES  KWUN TONG
# 1                        7-ELEVEN       RECHARGEABLE BATTERIES   TUEN MUN
#
#   Others Opening Hours Telephone Fax Number  / 傳真號碼  ... Country Park  \
# 0   N.A.          N.A.      N.A.               N.A.  ...          NaN
# 1   N.A.          N.A.      N.A.               N.A.  ...          NaN
#
#   Number of BBQ Pit Display Barbecue Sites Country Park/Special Area  \
# 0               NaN                    NaN                       NaN
# ...
